# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x = np.sin(np.linspace(0 , 1  , 20))
y = np.cos(np.linspace(0 , 1  , 20))
y
# Out:
# array([1.        , 0.99861528, 0.99446495, 0.9875605 , 0.97792106,
#        0.96557333, 0.95055149, 0.93289715, 0.91265921, 0.88989371,
#        0.8646637 , 0.83703905, 0.80709627, 0.77491828, 0.7405942 ,
#        0.70421909, 0.66589368, 0.62572411, 0.58382164, 0.54030231])

# %% [markdown]
# ## plot

# %%
plt.figure(figsize=(16 , 10))
plt.style.use("ggplot")
plt.plot(x , y  , "bo-")
plt.legend()
# Out:
# No handles with labels found to put in legend.

# %%
plt.figure(figsize=(10 , 6))
plt.plot(x**2 , y**3 , "go-" , label = "equation 1")
plt.plot(x*y , y**2 , "ro--" , label = "equation 2")
plt.legend(loc="best")
plt.title("two equation")
plt.show()

# %%
x = [1,2,4,5,6]
y = [2,4,8,10,12]
plt.figure(figsize=(15 , 10))
plt.style.use("classic")
plt.plot(x , y , "o" , markersize = 5 , linestyle = "")
plt.grid(True)
plt.show()

# %%
plt.style.use("ggplot")
days=[1,2,3,4,5,6,7]
max_t=[50,51,52,48,47,49,46]
min_t=[43,42,40,44,33,35,37]
avg_t=[45,48,48,46,40,42,40]
plt.plot(days, max_t, label="max")
plt.plot(days, min_t, label="min")
plt.plot(days, avg_t, label="average")
plt.legend(shadow = True , loc = "best")
plt.show()

# %% [markdown]
# ##     scatter

# %%
plt.figure(figsize=(9 , 6))
plt.style.use("ggplot")
plt.scatter(x , y ,c = x , s = 70 , alpha =1 )
plt.colorbar()

# %%
plt.style.use('seaborn')

x = [5, 7, 8, 5, 6, 7, 9, 2, 3, 4, 4, 4, 2, 6, 3, 6, 8, 6, 4, 1]
y = [7, 4, 3, 9, 1, 3, 2, 5, 2, 4, 8, 7, 1, 6, 4, 9, 7, 7, 5, 1]
plt.scatter(x,y , s = 50)
plt.show()

# %%
plt.xkcd()
plt.style.use('seaborn-deep')

x = [5, 7, 8, 5, 6, 7, 9, 2, 3, 4, 4, 4, 2, 6, 3, 6, 8, 6, 4, 1]
y = [7, 4, 3, 9, 1, 3, 2, 5, 2, 4, 8, 7, 1, 6, 4, 9, 7, 7, 5, 1]
plt.scatter(x,y , s = 100)
plt.grid(True)
plt.xlabel("Hey X")
plt.ylabel("Hey Y")
plt.title("Hey All")
plt.show()

# %% [markdown]
# ## Bie

# %%
plt.figure(figsize=(10 , 6))
plt.style.use("classic")
plt.pie([20,30,50,40,90] , labels=["egypt" , "morraco" , "mosco" , "etalia" , "tola"] , autopct="%1.1f%%" ,
        explode = [0,0,0,0,0.1] , shadow=True )
plt.axis("equal")
# Out:
# (-1.01563797321285, 1.0334879579567622, -1.112852406795262, 1.0258463880420494)

# %% [markdown]
# ## Bar

# %%
lables = ["A", "B", "C"]
values = [1,4 ,2]
bars = plt.bar(lables, values, color = "#034dad")
bars[0].set_hatch('/')
bars[1].set_hatch('o')
bars[2].set_hatch('*')
plt.show()

# %%
x = np.linspace(0 , 20 , 20)
y = np.random.randint(0 , 50 , 20)
x , y
# Out:
# (array([ 0.        ,  1.05263158,  2.10526316,  3.15789474,  4.21052632,
#          5.26315789,  6.31578947,  7.36842105,  8.42105263,  9.47368421,
#         10.52631579, 11.57894737, 12.63157895, 13.68421053, 14.73684211,
#         15.78947368, 16.84210526, 17.89473684, 18.94736842, 20.        ]),
#  array([26, 47, 12, 42, 14, 28, 46, 27, 28, 17, 35,  7, 21, 48, 34,  1, 43,
#         23,  6, 19]))

# %%
plt.figure(figsize=(10 , 6))
plt.style.use("bmh")
plt.bar(x , y , width=0.9 , facecolor="r" , edgecolor = "b" , alpha= 0.9)
plt.text(7 , -9 , "polulation Denisty"  , bbox = {"facecolor" : "blue" , "pad" : 10 , "alpha" : 0.5}  , style='italic')
for xx , yy in zip (x, y):
    plt.text(xx , yy , yy , ha = "center" , va = "bottom") ##va = "top"

# %%
company=['GOOGL','AMZN','MSFT','FB']
revenue=[90,136,85,27]
profit=[40,7,34,12]
xpos = np.arange(len(company)) # 0 , 1 , 2, 3

plt.bar(company,revenue, width=0.6, label="Revenue") # x = 0, x = 0.4 
plt.bar(xpos-0.4,profit, width=0.4,label="Profit")# x = -.4  , x = 0
plt.xticks(xpos,company)
plt.ylabel("Revenue(Bln)")
plt.title('US Technology Stocks')
plt.legend(loc = "best")
plt.show()

# %% [markdown]
# ## Histogram

# %%
x = [10,10,40,5,40,10,7,8,2,1,40,5,6]
plt.figure(figsize=(8 , 5))
plt.style.use("dark_background")
plt.hist( x , color="blue" , alpha=0.5)
# Out:
# (array([2., 5., 3., 0., 0., 0., 0., 0., 0., 3.]),
#  array([ 1. ,  4.9,  8.8, 12.7, 16.6, 20.5, 24.4, 28.3, 32.2, 36.1, 40. ]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# ## Hist2d

# %%
x = np.random.rand(200)
y = np.random.rand(200)
plt.figure(figsize=(12 , 10))
plt.hist2d(x , y )
plt.colorbar()

# %% [markdown]
# ## Subplot

# %%
x = np.linspace(0 , 15 , 6)
y = np.cos(x)
plt.figure(figsize=(13 , 5))
plt.style.use("ggplot")
plt.subplot(1 , 2 ,1)
plt.plot(x , y , "ko-")
plt.subplot(1 , 2 , 2)
plt.scatter(x , y , s=60 , c=[0.2,0.6,0.4,0.8,0.9,0.8])

# %%
plt.xkcd()
plt.style.use('seaborn-pastel')
plt.figure()


x = [5, 1, 8, 5, 6, 7, 9, 2, 3, 4, 4, 4, 2, 6, 3, 6, 8, 6, 4, 1]
y = [7, 4, 3, 9, 1, 3, 2, 5, 2, 4, 8, 7, 1, 6, 4, 9, 7, 7, 5, 1]


# first subplot 
plt.subplot(2,2,1)
plt.xlabel("Hey X")
plt.ylabel("Hey Y")
plt.scatter(x,y)


# second subplot 
plt.subplot(2,2,2)
plt.xlabel("Hey X")
plt.ylabel("Hey Y")
plt.plot(x,y, "k*")


# Third subplot 
plt.subplot(2,2,3)
plt.xlabel("Hey X")
plt.ylabel("Hey Y")
plt.plot(x,y, "ro")


# forth subplot 
plt.subplot(2,2,4)
plt.xlabel("Hey X")
plt.ylabel("Hey Y")
plt.plot(x,y, 'b>')




plt.show()

# %%
from IPython.display import HTML
url = 'http://jakevdp.github.io/downloads/videos/double_pendulum_xkcd.mp4'
HTML('<video controls alt="animation" src="{0}">'.format(url))
# Out:
# <video controls alt="animation" src="http://jakevdp.github.io/downloads/videos/double_pendulum_xkcd.mp4">

# %%
from IPython.display import YouTubeVideo
YouTubeVideo('hCvWSzJyHPk')

# %%
YouTubeVideo('hCvWSzJyHPk', width=1000, height=570)
